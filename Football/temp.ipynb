# %%
import pandas as pd
import matplotlib as plt
df = pd.read_csv('link.csv')
# Plot the link value distribution
df['Link value'].hist(bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
#       2 import matplotlib as plt
# ----> 3 df = pd.read_csv('link.csv')
#       4 # Plot the link value distribution
#       5 df['Link value'].hist(bins=20)
#
# ...

# %%
import pandas as pd

action_list = ['around_mound_zone', 'background_zone', 'door_zone', 'foraging_zone', 'left_sticks_area_zone', 'mound_zone', 'right_sand_area_zone', 'right_sticks_area_zone', 'sand_area_zone', 'waiting_area_zone', 'close_neighbour_around_mound_zone', 'close_neighbour_background_zone', 'close_neighbour_door_zone', 'close_neighbour_foraging_zone', 'close_neighbour_left_sticks_area_zone', 'close_neighbour_mound_zone', 'close_neighbour_right_sand_area_zone', 'close_neighbour_right_sticks_area_zone', 'close_neighbour_sand_area_zone', 'close_neighbour_waiting_area_zone', 'distant_neighbour_around_mound_zone', 'distant_neighbour_background_zone', 'distant_neighbour_door_zone', 'distant_neighbour_foraging_zone', 'distant_neighbour_left_sticks_area_zone', 'distant_neighbour_mound_zone', 'distant_neighbour_right_sand_area_zone', 'distant_neighbour_right_sticks_area_zone', 'distant_neighbour_sand_area_zone', 'distant_neighbour_waiting_area_zone', 'allogroom', 'carry_pup', 'dig_burrow', 'foraging', 'groom',
               'high_sitting/standing_(vigilant)', 'human_interaction', 'interact_with_pup', 'interacting_with_foreign_object', 'low_sitting/standing_(stationary)', 'lying/resting_(stationary)', 'moving', 'playfight', 'raised_guarding_(vigilant)', 'sunbathe', 'close_neighbour_allogroom', 'close_neighbour_carry_pup', 'close_neighbour_dig_burrow', 'close_neighbour_foraging', 'close_neighbour_groom', 'close_neighbour_high_sitting/standing_(vigilant)', 'close_neighbour_human_interaction', 'close_neighbour_interact_with_pup', 'close_neighbour_interacting_with_foreign_object', 'close_neighbour_low_sitting/standing_(stationary)', 'close_neighbour_lying/resting_(stationary)', 'close_neighbour_moving', 'close_neighbour_playfight', 'close_neighbour_raised_guarding_(vigilant)', 'close_neighbour_sunbathe', 'distant_neighbour_allogroom', 'distant_neighbour_carry_pup', 'distant_neighbour_dig_burrow', 'distant_neighbour_foraging', 'distant_neighbour_groom', 'distant_neighbour_high_sitting/standing_(vigilant)', 'distant_neighbour_human_interaction', 'distant_neighbour_interact_with_pup', 'distant_neighbour_interacting_with_foreign_object', 'distant_neighbour_low_sitting/standing_(stationary)', 'distant_neighbour_lying/resting_(stationary)', 'distant_neighbour_moving', 'distant_neighbour_playfight', 'distant_neighbour_raised_guarding_(vigilant)', 'distant_neighbour_sunbathe']
df = pd.DataFrame({
    'id': range(len(action_list)),
    'action': action_list
})
df.to_csv('fkeys/action_2.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("match_event.csv")
# max_match_folder = 10
# df = pd.DataFrame()
# for folder in range(max_match_folder):
#     df = pd.concat(
#             [df, pd.read_csv(f'matches/match_{folder}/match_data.csv')])

l = df['action'].value_counts()
print(l.to_dict())
print(sum(l.to_dict().values()))
l.plot(kind='bar')
plt.title("Frequencies of each action in match_event.csv")
plt.xlabel("Action")
plt.ylabel("Frequency")
plt.show()
# Out:
# {'Simple pass': 1207430, 'Ground attacking duel': 242409, 'Ground defending duel': 235084, 'Touch': 165041, 'Air duel': 145866, 'Ground loose ball duel': 125496, 'High pass': 123213, 'Head pass': 91193, 'Throw in': 78033, 'Cross': 58631, 'Clearance': 53160, 'Foul': 43958, 'Launch': 43296, 'Shot': 40458, 'Free Kick': 34049, 'Goal kick': 29532, 'Smart pass': 28427, 'Acceleration': 24376, 'Corner': 18050, 'Hand pass': 13135, 'Reflexes': 10190, 'Free kick cross': 8123, 'Save attempt': 6373, 'Goalkeeper leaving line': 5779, 'Free kick shot': 2038, 'Hand foul': 1934, 'Protest': 561, 'Penalty': 541, 'Out of game foul': 472, 'Late card foul': 300, 'Time lost foul': 205, 'Simulation': 108, 'Violent Foul': 74, 'Ball out of the field': 25, 'Whistle': 4}
# 2837564
